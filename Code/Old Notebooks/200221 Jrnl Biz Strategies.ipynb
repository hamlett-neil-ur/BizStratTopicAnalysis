# %% [markdown]
# ## Purpose.
#
# Here we collect abstracts and titles from [*International Journal of Business Strategy*](https://ijbs-journal.org/IJBS-JOURNAL/Default.aspx).  This information is to be used as part of an attempt to apply text classification to charting the progression of business strategy.
#
# ## Approach.
#
# Titles and abstracts are available without paywall login. But we have to do this in ***three stages***.
#
# ⓵ **Get the URL for the each volume**. We start with the journal's hope page.  Our essential information is embedded in a frame depicted below on the right-hand side of the page.
#
# ⓶ **Get a list of issue URLs**.  Each volume page contains thumbnail images of individual issues. These include URLs to the individual isses.
#
# ⓷ **Collect lists of titles**.  Follow each issue's URL to its issue table of contents. The tables of contents contain titles, as well as URLs to pages for individual articles.
#
# ⓸ **Collect abstracts**.  Abstracts are accessible from individual articles. We have to get the abstracts from these individual-article pages.

# %%
# Import libaries
import requests as req
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import itertools as it
import json
import io
from copy import deepcopy
import datetime

# %%
# We use lots of list-comprehension, which drives requests.get operations.
# We need to "throttle" these, so as to avoid the appearance of a DDoS
# attack.  We accomplish this by a get_sleep function.  This function 
# executes a req.get operation, returning the result, with a one-second
# delay.
def sleep_get(url, headers):
    time.sleep(np.random.uniform(low = 0.5,
                                 high = 2.3))
    return(req.get(url,
                   headers = headers))
#
# Partition a list into a specified number of bins.  Our inputs
# are:
# ⧐ parted_list is the list to be partitioned;
# ⧐ partition_counts specifies the number of bins into which
#   parted_list is divided.
# We produce an enumerated dictionary of the list partitions.
def partition_list(parted_list, partition_counts):
    parted_list = np.sort(np.array(parted_list))
    partition_len = int(np.ceil(len(parted_list)/partition_counts))
    partitions = [np.array(object = range(partition_len)) + part * partition_len
                     for part in range(partition_counts)]
    partitions[-1] = np.arange(start = partitions[-1][0],
                               stop = parted_list.shape[0])
    return dict(enumerate([list(parted_list[part])
                             for part in partitions]))

# %%
headers = {
    'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'
    }

BeautifulSoup(sleep_get('https://ijbs-journal.org/IJBS-JOURNAL/',
                        headers = headers).content,
              'lxml')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <style type="text/css">
#
#
# 	.banner-logo         {																			position:relative; TOP:20px;
# 								LEFT:84px;
# 																						WIDTH:44px; HEIGHT:44px; z-index: 3;														     			}
#
# 	.banner-before-Tit   {																			-webkit-column-width: 	45px; 	-moz-column-width: 45px; column-width: 	45px;														     	}
#
#
#
# 	.top-banner-Title    {					color: #000;
# 								font-size: 30pt;
# 								width: 800px; 														}
#
#
#
# 	.bot-banner-ISSNs    {					color: #000;
# 								font-size: 12pt;																}
#
# 	.top-banner-gradient {					background: linear-gradient(180deg, #669934, #9CCF60); 								height: 63px;	}
# 	.bot-banner-gradient {					background: linear-gradient(180deg, #9CCF60, #669934); 								height: 63px;	}				</style>
# <title>IJBS-JOURNAL</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <script src="js/jquery.min.js"></script>
# <script src="js/bootstrap.min.js"></script>
# <link href="Images/IABE_Logo.ico" rel="shortcut icon"/>
# <link href="css/main.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#
# 	function showActiveSubTrackMenu(){
#
# 	javascript:hideAllSubTracks()
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "11")
# 	div_Track_11_InternationalBusiness.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "2")
# 	div_Track_2_Accounting.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "3")
# 	div_Track_3_Economics.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "4")
# 	div_Track_4_Finance.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "5")
# 	div_Track_5_Management.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "6")
# 	div_Track_6_ManagementSci.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "7")
# 	div_Track_7_Marketing.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "8")
# 	div_Track_8_MIS_CIS.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "9")
# 	div_Track_9_POM.style.display="block"
#
# 	if (document.getElementById('dd_SubmittingAuthor_Tracks').value == "10")
# 	div_Track_10_Other.style.display="block"
#
#
# 	}
# </script>
# <script type="text/javascript">
# 	$(document).ready(
#  		function()
# 		{
#
# 	    			var tab = document.getElementById('hidTAB').value;
#
# 				if(tab == "image")
# 				{
# 					tab = "#div_TAB_home";
# 				}
#
# 	    			$( '#tabGroupOne a[href="' + tab + '"]' ).tab( 'show' );
#
# 				scroll(0,0);
#
# 				$('body, html, #wrapper').scrollTop(0);
# 		}
#
#
# 	);
#     </script>
# </head>
# <style type="text/css">
# .hover-item {
# 	background-image: url('images/Menu Mouseover Pic None.gif'); width:190px; height:20px;
# }
#
# .hover-item:hover {
# 	background-image: url('images/Menu Mouseover Pic.gif'); width:190px; height:20px;
# }
#
# .hover-item2 {
# 	background: linear-gradient(180deg, #FFFFFF, #EEEEEE);
# }
#
# .hover-item2:hover {
# 	background: linear-gradient(180deg, #016ACF, #319AFF);
# }
#
# .hover-link2 {
# 	color: #1E90FF;;
# }
#
# .hover-link2:hover {
# 	color: #973164;
# }
#
#
# .hover-link {
# 	color: #016ACF;
# }
#
# .hover-link:hover {
# 	color: #973164;
# }
#
# .hover-link:focus {
# 	outline:0;
# }
#
# .focus-border {
#
# }
#
# .focus-border:focus {
# 	outline:0;
# }
#
#
# .top-menu {
#
# 		padding-left:8px;
# 		padding-right:8px;
# 		height: 38px;
# 		display: table-cell;
# 		vertical-align: middle;
# 		border: none;
# 		background-color: transparent;
# 		color: #fff;
# }
#
# .top-menu:hover {
#
# 	outline:0;
# 	background-color: #016ACF;
# 	text-align: center;
#
# }
#
# .top-menu:focus {
#
# 	outline:0;
# 	background-color: #016ACF;
# 	text-align: center;
#
# }
#
# .top-menu:active {
#
# 	outline:0;
# 	background-color: #fff;
#
# }
#
#
#
#
# .top-menu-btn {
#
# 		padding-left:8px;
# 		padding-right:8px;
# 		height: 38px;
# 		display: table-cell;
# 		vertical-align: middle;
# 		border: none;
# 		background-color: transparent;
# 		color: #fff;
# }
#
# .top-menu-btn:hover {
#
# 	outline:0;
# 	background-color: transparent;
# 	text-align: center;
#
# }
#
# .top-menu-btn:focus {
#
# 	outline:0;
# 	background-color: transparent;
# 	text-align: center;
#
# }
#
# .top-menu-btn:active {
#
# 	outline:0;
# 	background-color: transparent;
#
# }
#
# .top-box
# {
#     box-shadow: inset 0 20px 30px -20px rgba(0,0,0,1);
# }
# .left-box
# {
#     box-shadow: inset 7px 0 9px -7px rgba(0,0,0,0.4);
# }
# .right-box
# {
#     box-shadow: inset -7px 0 9px -7px rgba(0,0,0,0.4);
# }
# .bottom-box
# {
#     box-shadow: inset 0 -7px 9px -7px rgba(0,0,0,0.4);
# }
#
# ::-webkit-input-placeholder { /* Chrome */
#   color: #7A9CD3;
#   font-style: italic;
#   text-align: center;
# }
# :-ms-input-placeholder { /* IE 10+ */
#   color: #7A9CD3;
#   font-style: italic;
#   text-align: center;
# }
# ::-moz-placeholder { /* Firefox 19+ */
#   color: #7A9CD3;
#   font-style: italic;
#   opacity: 1;
#   text-align: center;
# }
# :-moz-placeholder { /* Firefox 4 - 18 */
#   color: #7A9CD3;
#   font-style: italic;
#   opacity: 1;
#   text-align: center;
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .border-tb {
# 		border-top-left-radius: 20px;
# 		border-bottom-left-radius: 20px;
# 		text-indent: 10px;
# }
#
# .border-tb:hover {
# 			outline:0;
# }
#
# .border-tb:focus {
# 			outline:0;
# }
#
# .border-tb:active {
# 			outline:0;
# }
#
#
# input[type="checkbox"] + label:before {
#   border: 1px solid #7f83a2;
#   content: "\00a0";
#   display: inline-block;
#   font: 16px/1em sans-serif;
#   height: 16px;
#   margin: 0 .25em 0 0;
#   padding: 0;
#   vertical-align: top;
#   width: 16px;
# }
#
# input[type="checkbox"]:checked + label:before {
#   background: #ffffff;
#   color: #ffffff;
#   content: "\2713";
#   text-align: center;
# }
#
# input[type="checkbox"]:checked + label:after {
#   font-weight: bold;
# }
#
# .double {
#   zoom:1.2;
#   transform:scale(1.2);
#   -ms-transform:scale(1.2);
#   -webkit-transform:scale(1.2);
#   -o-transform:scale(1.2);
#   -moz-transform:scale(1.2);
#   transform-origin:0 0;
#   -ms-transform-origin:0 0;
#   -webkit-transform-origin:0 0;
#   -o-transform-origin:0 0;
#   -moz-transform-origin:0 0;
#   -webkit-transform-origin:0 0;
# }
#
#
#
# </style>
# <script type="text/javascript">
# 	function hideAllSubTracks(){
#
# div_Track_11_InternationalBusiness.style.display="none"
# div_Track_2_Accounting.style.display="none"
# div_Track_3_Economics.style.display="none"
# div_Track_4_Finance.style.display="none"
# div_Track_5_Management.style.display="none"
# div_Track_6_ManagementSci.style.display="none"
# div_Track_7_Marketing.style.display="none"
# div_Track_8_MIS_CIS.style.display="none"
# div_Track_9_POM.style.display="none"
# div_Track_10_Other.style.display="none"
#
# }
# </script>
# <script type="text/javascript">
#
#
# 	$("[id*=CheckBoxList1] input:checkbox").change(function () {
#           var maxSelection = 3;
#           if ($("[id*=CheckBoxList1] input:checkbox:checked").length > maxSelection) {
#               $(this).prop("checked", false);
#               alert("Please select a maximum of " + maxSelection + " items.");
#           }
#       	})
#
#
#
# 	function dd_Editorial_Check_For_US(){
#     		var value = document.getElementById("dd_Country_Editorial").options[document.getElementById("dd_Country_Editorial").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_Editorial_State_Section.style.display="block";
# 				dd_Editorial_State_US.style.display="block";
# 				tb_Editorial_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_Editorial_State_Section.style.display="none";
# 				dd_Editorial_State_US.style.display="none";
# 				tb_Editorial_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_Editorial_State_Section.style.display="block";
# 				dd_Editorial_State_US.style.display="none";
# 				tb_Editorial_State.style.display="block";
# 		}
# 	}
#
# 	function dd_SubmittingAuthor_Check_For_US(){
#     		var value = document.getElementById("dd_Country_SubmittingAuthor").options[document.getElementById("dd_Country_SubmittingAuthor").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_SubmittingAuthor_State_Section.style.display="block";
# 				dd_SubmittingAuthor_State_US.style.display="block";
# 				tb_SubmittingAuthor_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_SubmittingAuthor_State_Section.style.display="none";
# 				dd_SubmittingAuthor_State_US.style.display="none";
# 				tb_SubmittingAuthor_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_SubmittingAuthor_State_Section.style.display="block";
# 				dd_SubmittingAuthor_State_US.style.display="none";
# 				tb_SubmittingAuthor_State.style.display="block";
# 		}
# 	}
#
# 	function dd_Reviewer_Check_For_US(){
#     		var value = document.getElementById("dd_Country_Reviewer").options[document.getElementById("dd_Country_Reviewer").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_Reviewer_State_Section.style.display="block";
# 				dd_Reviewer_State_US.style.display="block";
# 				tb_Reviewer_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_Reviewer_State_Section.style.display="none";
# 				dd_Reviewer_State_US.style.display="none";
# 				tb_Reviewer_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_Reviewer_State_Section.style.display="block";
# 				dd_Reviewer_State_US.style.display="none";
# 				tb_Reviewer_State.style.display="block";
# 		}
# 	}
#
#
# 	function dd_Author02_Check_For_US(){
#     		var value = document.getElementById("dd_Author02_Country").options[document.getElementById("dd_Author02_Country").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_Author02_State_Section.style.display="block";
# 				dd_Author02_State.style.display="block";
# 				tb_Author02_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_Author02_State_Section.style.display="none";
# 				dd_Author02_State.style.display="none";
# 				tb_Author02_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_Author02_State_Section.style.display="block";
# 				dd_Author02_State.style.display="none";
# 				tb_Author02_State.style.display="block";
# 		}
# 	}
#
# 	function dd_Author03_Check_For_US(){
#     		var value = document.getElementById("dd_Author03_Country").options[document.getElementById("dd_Author03_Country").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_Author03_State_Section.style.display="block";
# 				dd_Author03_State.style.display="block";
# 				tb_Author03_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_Author03_State_Section.style.display="none";
# 				dd_Author03_State.style.display="none";
# 				tb_Author03_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_Author03_State_Section.style.display="block";
# 				dd_Author03_State.style.display="none";
# 				tb_Author03_State.style.display="block";
# 		}
# 	}
#
# 	function dd_Author04_Check_For_US(){
#     		var value = document.getElementById("dd_Author04_Country").options[document.getElementById("dd_Author04_Country").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_Author04_State_Section.style.display="block";
# 				dd_Author04_State.style.display="block";
# 				tb_Author04_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_Author04_State_Section.style.display="none";
# 				dd_Author04_State.style.display="none";
# 				tb_Author04_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_Author04_State_Section.style.display="block";
# 				dd_Author04_State.style.display="none";
# 				tb_Author04_State.style.display="block";
# 		}
# 	}
#
# 	function dd_Author05_Check_For_US(){
#     		var value = document.getElementById("dd_Author05_Country").options[document.getElementById("dd_Author05_Country").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_Author05_State_Section.style.display="block";
# 				dd_Author05_State.style.display="block";
# 				tb_Author05_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_Author05_State_Section.style.display="none";
# 				dd_Author05_State.style.display="none";
# 				tb_Author05_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_Author05_State_Section.style.display="block";
# 				dd_Author05_State.style.display="none";
# 				tb_Author05_State.style.display="block";
# 		}
# 	}
#
# 	function dd_Author06_Check_For_US(){
#     		var value = document.getElementById("dd_Author06_Country").options[document.getElementById("dd_Author06_Country").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_Author06_State_Section.style.display="block";
# 				dd_Author06_State.style.display="block";
# 				tb_Author06_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_Author06_State_Section.style.display="none";
# 				dd_Author06_State.style.display="none";
# 				tb_Author06_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_Author06_State_Section.style.display="block";
# 				dd_Author06_State.style.display="none";
# 				tb_Author06_State.style.display="block";
# 		}
# 	}
#
# 	function dd_Subscriber_Check_For_US(){
#     		var value = document.getElementById("dd_Country_Subscriber").options[document.getElementById("dd_Country_Subscriber").selectedIndex].value;
#
# 		if (value == "United States")
# 		{
# 			div_Subscriber_State_Section.style.display="block";
# 				dd_Subscriber_State_US.style.display="block";
# 				tb_Subscriber_State.style.display="none";
# 		}
# 		else if (value == "Select Country")
# 		{
# 			div_Subscriber_State_Section.style.display="none";
# 				dd_Subscriber_State_US.style.display="none";
# 				tb_Subscriber_State.style.display="none";
# 		}
# 		else
# 		{
# 			div_Subscriber_State_Section.style.display="block";
# 				dd_Subscriber_State_US.style.display="none";
# 				tb_Subscriber_State.style.display="block";
# 		}
# 	}
#
# 	$(function(){$(    '#changeTabToHomeFromTopMenu'                      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_home";                		       $('#tabGroupOne a[href=     "#div_TAB_home"                        ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_AimAndScopeFromTopMenu'       ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_AimAndScope";         		       $('#tabGroupOne a[href=     "#div_TAB_AimAndScope"                 ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_IABEFromTopMenu'              ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_IABE";                		       $('#tabGroupOne a[href=     "#div_TAB_IABE"	                  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_JournalsFromTopMenu'          ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Journals";            		       $('#tabGroupOne a[href=     "#div_TAB_Journals"	                  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_EditorialBoardFromTopMenu'    ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_EditorialBoard";      		       $('#tabGroupOne a[href=     "#div_TAB_EditorialBoard"              ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_SubmissionFromTopMenu'        ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Submission";          		       $('#tabGroupOne a[href=     "#div_TAB_Submission"                  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_CurrentFromTopMenu'           ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Current";             		       $('#tabGroupOne a[href=     "#div_TAB_Current"                     ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_ArchiveFromTopMenu'           ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Archive";             		       $('#tabGroupOne a[href=     "#div_TAB_Archive"                     ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_IndexFromTopMenu'             ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Index";               		       $('#tabGroupOne a[href=     "#div_TAB_Index"                       ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_FAQFromTopMenu'               ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_FAQ";                 		       $('#tabGroupOne a[href=     "#div_TAB_FAQ"                         ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
#
# 	$(function(){$(    '#changeTabToHomeFromLeftMenu'                      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_home";               		       $('#tabGroupOne a[href=     "#div_TAB_home"                        ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_AimAndScopeFromLeftMenu'       ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_AimAndScope";        		       $('#tabGroupOne a[href=     "#div_TAB_AimAndScope"                 ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_IABEFromLeftMenu'              ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_IABE";               		       $('#tabGroupOne a[href=     "#div_TAB_IABE"                        ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_JournalsFromLeftMenu'          ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Journals";            		       $('#tabGroupOne a[href=     "#div_TAB_Journals"	                  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_EditorialBoardFromLeftMenu'    ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_EditorialBoard";     		       $('#tabGroupOne a[href=     "#div_TAB_EditorialBoard"              ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_SubmissionFromLeftMenu'        ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Submission";         		       $('#tabGroupOne a[href=     "#div_TAB_Submission"                  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_CurrentFromLeftMenu'           ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Current";            		       $('#tabGroupOne a[href=     "#div_TAB_Current"                     ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_ArchiveFromLeftMenu'           ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Archive";            		       $('#tabGroupOne a[href=     "#div_TAB_Archive"                     ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_IndexFromLeftMenu'             ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Index";              		       $('#tabGroupOne a[href=     "#div_TAB_Index"                       ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_FAQFromLeftMenu'               ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_FAQ";                		       $('#tabGroupOne a[href=     "#div_TAB_FAQ"                         ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_ContactUs'                     ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_ContactUs";			       $('#tabGroupOne a[href=     "#div_TAB_ContactUs"                   ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_PubEthics'                     ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_PubEthics";			       $('#tabGroupOne a[href=     "#div_TAB_PubEthics"                   ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_MalStatement'                  ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_MalStatement";			       $('#tabGroupOne a[href=     "#div_TAB_MalStatement"                ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_OnlineAccessFromLeftMenu'      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_OnlineAccess";         	       $('#tabGroupOne a[href=     "#div_TAB_OnlineAccess"                ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
#
# 	$(function(){$(    '#changeTabTodiv_TAB_CFPFromLeftMenu'               ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_CFP";                		       $('#tabGroupOne a[href=     "#div_TAB_CFP"                         ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
# 	$(function(){$(    '#changeTabTodiv_TAB_PaperReviewer'                 ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_PaperReviewer";              	       $('#tabGroupOne a[href=     "#div_TAB_PaperReviewer"               ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabToReviewerGuidelines'                    ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_ReviewerGuidelines";         	       $('#tabGroupOne a[href=     "#div_TAB_ReviewerGuidelines"          ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_ReviewerEthicalGuidelines'     ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_ReviewerEthicalGuidelines";  	       $('#tabGroupOne a[href=     "#div_TAB_ReviewerEthicalGuidelines"   ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
# 	$(function(){$(    '#changeTabToAuthorSubmitGuidelines'                ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_AuthorSubmitGuidelines";     	       $('#tabGroupOne a[href=     "#div_TAB_AuthorSubmitGuidelines"      ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabToAuthorSubmitGuidelines2'               ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_AuthorSubmitGuidelines";     	       $('#tabGroupOne a[href=     "#div_TAB_AuthorSubmitGuidelines"      ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabToAuthorEthicalGuidelines'               ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_AuthorEthicalGuidelines";    	       $('#tabGroupOne a[href=     "#div_TAB_AuthorEthicalGuidelines"     ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabToCopyrightPolicy'                       ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_changeTabToCopyrightPolicy";          $('#tabGroupOne a[href=     "#div_TAB_changeTabToCopyrightPolicy"  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabToCopyrightPolicy2'                       ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_changeTabToCopyrightPolicy";         $('#tabGroupOne a[href=     "#div_TAB_changeTabToCopyrightPolicy"  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabToCopyrightPolicy3'                       ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_changeTabToCopyrightPolicy";         $('#tabGroupOne a[href=     "#div_TAB_changeTabToCopyrightPolicy"  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
#
# 	$(function(){$(    '#changeTabTodiv_TAB_EditorialBoardEditor'          ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_EditorialBoardEditor";       	       $('#tabGroupOne a[href=     "#div_TAB_EditorialBoardEditor"        ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabToEditorGuidelines'                      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_EditorGuidelines";           	       $('#tabGroupOne a[href=     "#div_TAB_EditorGuidelines"            ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
# 	$(function(){$(    '#changeTabToSearch'                                ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Search";                     	       $('#tabGroupOne a[href=     "#div_TAB_Search"		          ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_BP'	                       ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_BP";                     	       $('#tabGroupOne a[href=     "#div_TAB_BP"		          ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
# 	$(function(){$(    '#changeTabTodiv_TAB_SubscriptionFromLeftMenu'      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Subscription";                        $('#tabGroupOne a[href=     "#div_TAB_Subscription"	          ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
# 	$(function(){$(    '#changeTabTodiv_TAB_Submission'                    ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Submission";         		       $('#tabGroupOne a[href=     "#div_TAB_Submission"                  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
# 	$(function(){$(    '#changeTabTodiv_TAB_OnlineAccess'                  ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_OnlineAccess";                        $('#tabGroupOne a[href=     "#div_TAB_OnlineAccess"                ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabBackTodiv_TAB_SubscriptionFromLeftMenu'  ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Subscription";                        $('#tabGroupOne a[href=     "#div_TAB_Subscription"	          ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabBackTodiv_TAB_PaperReviewer'             ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_PaperReviewer";              	       $('#tabGroupOne a[href=     "#div_TAB_PaperReviewer"               ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabBackTodiv_TAB_EditorialBoardEditor'      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_EditorialBoardEditor";       	       $('#tabGroupOne a[href=     "#div_TAB_EditorialBoardEditor"        ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabBackTodiv_TAB_Submission'                ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Submission";         		       $('#tabGroupOne a[href=     "#div_TAB_Submission"                  ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabBackTodiv_TAB_OnlineAccess'              ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_OnlineAccess";                        $('#tabGroupOne a[href=     "#div_TAB_OnlineAccess"                ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_Privacy1'                      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Privacy1";       	               $('#tabGroupOne a[href=     "#div_TAB_Privacy1"                    ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_Privacy2'                      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Privacy2";       	               $('#tabGroupOne a[href=     "#div_TAB_Privacy2"                    ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_Privacy3'                      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Privacy3";       	               $('#tabGroupOne a[href=     "#div_TAB_Privacy3"                    ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_Privacy4'                      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Privacy4";       	               $('#tabGroupOne a[href=     "#div_TAB_Privacy4"                    ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
# 	$(function(){$(    '#changeTabTodiv_TAB_Privacy5'                      ).click(function(e){e.preventDefault();scroll(0,0);document.getElementById('hidTAB').value =     "#div_TAB_Privacy5";       	               $('#tabGroupOne a[href=     "#div_TAB_Privacy5"                    ]').tab('show');	$('body, html, #div_Paper').scrollTop(0);})})
#
#
# </script>
# <body style="background-color: #eee">
# <form action="default.aspx" id="form1" method="post" name="form1" onsubmit="javascript:return WebForm_OnSubmit();">
# <div>
# <input id="__EVENTTARGET" name="__EVENTTARGET" type="hidden" value=""/>
# <input id="__EVENTARGUMENT" name="__EVENTARGUMENT" type="hidden" value=""/>
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# </div>
# <script type="text/javascript">
# //<![CDATA[
# var theForm = document.forms['form1'];
# if (!theForm) {
#     theForm = document.form1;
# }
# function __doPostBack(eventTarget, eventArgument) {
#     if (!theForm.onsubmit || (theForm.onsubmit() != false)) {
#         theForm.__EVENTTARGET.value = eventTarget;
#         theForm.__EVENTARGUMENT.value = eventArgument;
#         theForm.submit();
#     }
# }
# //]]>
# </script>
# <script src="/IJBS-JOURNAL/WebResource.axd?d=bZRHUxRpMC2x2q60aJhj7XY01bstjtQ-Xkq09MuhtEG25egzBH-dFmRLY7Vtk7we0TDJ3oUvo7cuRyleF1CAG4fsHeY1&amp;t=636040172080000000" type="text/javascript"></script>
# <script src="/IJBS-JOURNAL/ScriptResource.axd?d=jCuQLYzp02jxZcs7Bj1LMsoY5hHw-1UO0lCQizc8bgD5BY8xraElsvfGhhBWM8-MhnxKUoir0-8jMgOzFO-1EKdxEUJZ-Ngvvzut3IF4_V0X-Sn7m55mNA2hFFY9_1ZBAFF1e9oER1MlUho8e_jedgOeORc1&amp;t=3f4a792d" type="text/javascript"></script>
# <script src="/IJBS-JOURNAL/ScriptResource.axd?d=CBxQcvBUQLWGgbo7PFs9D279ef3Np_oxCOh8rr8D3NyWLuN09thnKerHuWSOhnvlTSm0ZAiZ9U6Hme3qKnR7n3FgvdL237K9jzcwUZVmmsbwAP6RJ2_IgeeoZMWV6httmN95nS_vKlk4qkixnUaTymA_AfFsw1MeAXVg68mVQ6n8X42j0&amp;t=3f4a792d" type="text/javascript"></script>
# <script src="/IJBS-JOURNAL/ScriptResource.axd?d=xXwkIXNArisPOCrslbBIHR8aUjcnjiC88EBxr2ypwQtker3_W54nKWJ3ufESE-OoiD6nPrA35h9EGTBqistC-Hx0h55tCgiAiIixIqb6c4FyHYccj0545NZFO7O5nq8C_x4OcrjqET9uV2q9truJiPZfXhA1&amp;t=ffffffffcb21d4c0" type="text/javascript"></script>
# <script src="/IJBS-JOURNAL/ScriptResource.axd?d=5FCL1K23zhPrvwlaFLMIVBEKti_SDpqAcq1-xPCbRgAtm4UjqftjLcdLUq1hC63x3ZxTHnQsXSJ6gR6rWgAyGK1rWAHzUQYsDwCI9sM1Ns6BQ7Ww_THu4YCtzoz09R1Y6ii_qI5WBltX-glu_1Lz-CQtWv41&amp;t=ffffffffcb21d4c0" type="text/javascript"></script>
# <script src="/IJBS-JOURNAL/ScriptResource.axd?d=p-8V9QL85fArVWU1__B4w9rJcKwD_7_IlpcCzXjjr-G8aT_dUCnGoluqUSMk_Qp4xlSv1NYw28FpYL9IUV9hQWC3pB66lt-mVK4Gt2w1lXZ6JzgxpUOAaX1Rr-DLEQTe2DBqBdq4xY6MK7OQKV3XPwpaAySnhfI9tJDr8wS57tRD-vHN0&amp;t=ffffffffcb21d4c0" type="text/javascript"></script>
# <script type="text/javascript">
# //<![CDATA[
# function WebForm_OnSubmit() {
# null;
# return true;
# }
# //]]>
# </script>
# <div>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="0CE62EBC"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="..."/>
# </div>
# <div id="div_WorkSpace1" style="width: 1024px; margin:0 auto; background-color: #FFFFFF; min-width: 480px">
# <div style="position: fixed; z-index: 3;"><img class="banner-logo" src="images/IABE.gif"/></div>
# <header>
# <div id="div_Top" style="position: fixed; top: 0; width: 1024px; z-index: 1; overflow: hidden; background-color: #FFFFFF; padding-bottom: 0px">
# <div class="top-banner-gradient" id="div_Fade1">
# <div style="padding-top: 10px; padding-bottom: 10pt;">
# <table width="100%">
# <tr>
# <td class="banner-before-Tit">&amp;nbsp</td>
# <td valign="middle">
# <div style="text-align: center;"><h4><span class="top-banner-Title" id="lbl_JournalTitle">International Journal of Business Strategy</span></h4></div>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <div class="bot-banner-gradient" id="div_Fade2">
# <table width="100%">
# <tr>
# <td>
# <div style="text-align: center; padding-top: 10pt;"><h4><span class="bot-banner-ISSNs"><b>ISSN:&amp;nbsp<span id="lbl_ISSN">1553-9563</span>,&amp;nbsp&amp;nbspE-ISSN:&amp;nbsp<span id="lbl_eISSN">2378-8585</span></b></span></h4></div>
# </td>
# </tr>
# </table>
# </div>
# <ul class="nav nav-tabs" id="tabGroupOne" style="width: 100%;" visible="false">
# <li class="active" style="display: none;"><a data-toggle="tab" href="#div_TAB_Blank">&amp;nbsp</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_home">Aim and Scope</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_AimAndScope">Aim and Scope</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_IABE">IABE</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Journals">Journals</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_EditorialBoard">Editorial Board</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Submission">Submission</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Current">Current</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Archive">Archive</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Index">Index</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_FAQ">FAQ</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_AuthorSubmitGuidelines">Author Guidelines</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_AuthorEthicalGuidelines">Author Ethical Guidelines</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_changeTabToCopyrightPolicy">Copyright Policy</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_CFP">Call For Papers</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_PaperReviewer">Sign up as a Paper Reviewer</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_ReviewerGuidelines">Reviewer Guidelines</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_ReviewerEthicalGuidelines">Reviewer Ethical Considerations</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_EditorialBoardEditor">Editorial Board Application</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_EditorGuidelines">Editor Guidelines</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Search">Search Articles</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_BP">Best Paper</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Subscription">Subscription</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_ContactUs">ContactUs</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_PubEthics">Publication Ethics</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_MalStatement">Malpractice Statement</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_OnlineAccess">Online Access</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Privacy1">Privacy</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Privacy2">Privacy</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Privacy3">Privacy</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Privacy4">Privacy</a></li>
# <li style="display: none;"><a data-toggle="tab" href="#div_TAB_Privacy5">Privacy</a></li>
# </ul>
# <span style="font-size: 12pt;">
# <div style="background-color: #000; width: 100%; height: 38px">
# <span style="font-size: 16px">
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#home" id="changeTabToHomeFromTopMenu" type="button">
# 										Aim and Scope
# 									</button>
# </div>
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#IABE" id="changeTabTodiv_TAB_IABEFromTopMenu" type="button">
# 										IABE
# 									</button>
# </div>
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#Journals" id="changeTabTodiv_TAB_JournalsFromTopMenu" type="button">
# 										Journals
# 									</button>
# </div>
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#div_TAB_EditorialBoard" id="changeTabTodiv_TAB_EditorialBoardFromTopMenu" type="button">
# 										Editorial Board
# 									</button>
# </div>
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#div_TAB_Submission" id="changeTabTodiv_TAB_SubmissionFromTopMenu" type="button">
# 										Paper Submission
# 									</button>
# </div>
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#div_TAB_Current" id="changeTabTodiv_TAB_CurrentFromTopMenu" type="button">
# 										Current
# 									</button>
# </div>
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#div_TAB_Archive" id="changeTabTodiv_TAB_ArchiveFromTopMenu" type="button">
# 										Archive
# 									</button>
# </div>
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#div_TAB_Index" id="changeTabTodiv_TAB_IndexFromTopMenu" type="button">
# 										Index
# 									</button>
# </div>
# <div class="top-menu" style="height: 38px; display: block; float: left">
# <button class="top-menu-btn" href="#div_TAB_FAQ" id="changeTabTodiv_TAB_FAQFromTopMenu" type="button">
# 										FAQ
# 									</button>
# </div>
# </span>
# </div>
# </span>
# </div>
# </header>
# <section>
# <div id="wrapper">
# <div id="first">
# <div style="padding-left: 10px; padding-right: 10px; margin-top:175px; position: relative; ">
# <div id="div_Menu1" style="box-shadow: -3px 3px 3px black; background: #555555; height: 32px; border-top-left-radius: 10px; border-top-right-radius: 10px; width: 170px; display: table-cell; vertical-align:middle; padding-left: 0px;">
# <span style="color: #fff; font-size: 14pt; padding-left: 16px;">Menu</span>
# <div id="div_Menu1_Body" style="border-style: solid; border-width: 2px; border-color: #555555; ">
# <div id="tabGroupTwo" style="width: 180px; padding-left: 0px; list-style-type: none; background-color: #f8f8f8;">
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 6px; padding-bottom: 3px; "><button class="focus-border" href="#home" id="changeTabToHomeFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Aim and Scope</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#IABE" id="changeTabTodiv_TAB_IABEFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">IABE</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#Journals" id="changeTabTodiv_TAB_JournalsFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Journals</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#EditorialBoard" id="changeTabTodiv_TAB_EditorialBoardFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Editorial Board</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#Submission" id="changeTabTodiv_TAB_SubmissionFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Paper Submission</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#Current" id="changeTabTodiv_TAB_CurrentFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Current</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#Archive" id="changeTabTodiv_TAB_ArchiveFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Archive</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#Index" id="changeTabTodiv_TAB_IndexFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Index</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#PubEthics" id="changeTabTodiv_TAB_PubEthics" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Publication Ethics</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#MalStatement" id="changeTabTodiv_TAB_MalStatement" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Malpractice Statement</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#FAQ" id="changeTabTodiv_TAB_FAQFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">FAQ</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#Subscription" id="changeTabTodiv_TAB_SubscriptionFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Subscription</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#OnlineAccess" id="changeTabTodiv_TAB_OnlineAccessFromLeftMenu" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Online Access</div></span></button></div>
# <div class="hover-item2" style="color: #000; padding-left: 0px; padding-top: 3px; padding-bottom: 3px; "><button class="focus-border" href="#ContactUs" id="changeTabTodiv_TAB_ContactUs" style="border: none; width: 100%; text-align: left; background-color: transparent; color: #000;" type="button"><span style="font-size: 11pt;"><div style="padding-left: 8px">Contact Us</div></span></button></div>
# </div>
# </div>
# </div>
# </div>
# <div style="padding-left: 10px; padding-right: 10px; margin-top:20px; position: relative; ">
# <div id="div_Menu2" style="box-shadow: -3px 3px 3px black; background-color: #555555; height: 32px; border-top-left-radius: 10px; border-top-right-radius: 10px; width: 170px; display: table-cell; vertical-align:middle; padding-left: 0px;">
# <span style="color: #fff; font-size: 12pt; padding-left: 8px;">Call For Papers</span>
# <div id="div_Menu2_Body" style="border-style: solid; border-width: 2px; border-color: #555555; ">
# <div id="tabGroupThree" style="width: 180px; padding-left: 0px; list-style-type: none; background-color: #f8f8f8;">
# <div style="color: #000; padding-right: 8px; padding-left: 8px; padding-top: 3px; padding-bottom: 3px;"><i>
#
#
#
# The&amp;nbspInternational Journal of Business Strategy (IJBS)&amp;nbspis a peer reviewed journal published by the IABE.<br/>
# <hr style="height:4pt; visibility:hidden; margin: 0; padding: 0"/>
# 		  The&amp;nbspIJBS&amp;nbspEditorial Board is inviting all papers relating to the following topics...
#
#
#
#
# 							</i></div>
# ...
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <span style="font-size: 10pt;">
# <table width="100%">
# <tr>
# <td width="2%">&amp;nbsp</td>
# <td valign="top" width="20%"><a href="https://jibe-journal.org" style="background-color: transparent;"><img alt="" height="200px" src="images\Journals\Covers\JIBE.jpg" style="margin:auto; display:inline-block; border-top: 1px solid #DDDDDD; border-right: 1px solid #DDDDDD; border-radius: 0; box-shadow: -2px 2px 2px #444444;" width="151px"/></a></td>
# <td width="2%">&amp;nbsp</td>
# <td valign="top">
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Title:</b></td><td valign="top"><a class="hover-link" href="https://jibe-journal.org" style="background-color: transparent;">JOURNAL OF INTERNATIONAL BUSINESS AND ECONOMICS</a></td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>ISSN:</b></td><td valign="top">1544-8037</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>E-ISSN:</b></td><td valign="top">2378-9174</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Frequency:</b></td><td valign="top">3 to 4 Issues Per Year</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Acceptance:</b></td><td valign="top">18% of submitted papers</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Editor's E-mail:</b></td><td valign="top"><a href="mailto:editor@jibe-journal.org" style="background-color: transparent; text-transform: lowercase;"><div class="hover-link" style="display: inline-block;">editor@jibe-journal.org</div></a></td></tr>
# </table>
# </td>
# <td width="1%">&amp;nbsp</td>
# </tr>
# </table>
# </span>
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <hr style="height:1pt; margin: 0; padding: 0" width="100%"/>
# </div>
# </td>
# </tr><tr>
# <td valign="top">
# <div style="border: none;" width="100%">
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <span style="font-size: 10pt;">
# <table width="100%">
# <tr>
# <td width="2%">&amp;nbsp</td>
# <td valign="top" width="20%"><a href="https://jife-journal.org" style="background-color: transparent;"><img alt="" height="200px" src="images\Journals\Covers\JIFE.jpg" style="margin:auto; display:inline-block; border-top: 1px solid #DDDDDD; border-right: 1px solid #DDDDDD; border-radius: 0; box-shadow: -2px 2px 2px #444444;" width="151px"/></a></td>
# <td width="2%">&amp;nbsp</td>
# <td valign="top">
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Title:</b></td><td valign="top"><a class="hover-link" href="https://jife-journal.org" style="background-color: transparent;">JOURNAL OF INTERNATIONAL FINANCE AND ECONOMICS</a></td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>ISSN:</b></td><td valign="top">1555-6336</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>E-ISSN:</b></td><td valign="top">2378-864X</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Frequency:</b></td><td valign="top">2 to 4 Issues Per Year</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Acceptance:</b></td><td valign="top">18% of submitted papers</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Editor's E-mail:</b></td><td valign="top"><a href="mailto:editor@jife-journal.org" style="background-color: transparent; text-transform: lowercase;"><div class="hover-link" style="display: inline-block;">editor@jife-journal.org</div></a></td></tr>
# </table>
# </td>
# <td width="1%">&amp;nbsp</td>
# </tr>
# </table>
# </span>
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <hr style="height:1pt; margin: 0; padding: 0" width="100%"/>
# </div>
# </td>
# </tr><tr>
# <td valign="top">
# <div style="border: none;" width="100%">
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <span style="font-size: 10pt;">
# <table width="100%">
# <tr>
# <td width="2%">&amp;nbsp</td>
# <td valign="top" width="20%"><a href="https://jifs-journal.org" style="background-color: transparent;"><img alt="" height="200px" src="images\Journals\Covers\JIFS.jpg" style="margin:auto; display:inline-block; border-top: 1px solid #DDDDDD; border-right: 1px solid #DDDDDD; border-radius: 0; box-shadow: -2px 2px 2px #444444;" width="151px"/></a></td>
# <td width="2%">&amp;nbsp</td>
# <td valign="top">
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Title:</b></td><td valign="top"><a class="hover-link" href="https://jifs-journal.org" style="background-color: transparent;">JOURNAL OF INTERNATIONAL FINANCE STUDIES</a></td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>ISSN:</b></td><td valign="top">1945-2950</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>E-ISSN:</b></td><td valign="top">2378-8674</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Frequency:</b></td><td valign="top">1 to 2 Issues Per Year</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Acceptance:</b></td><td valign="top">23% of submitted papers</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Editor's E-mail:</b></td><td valign="top"><a href="mailto:editor@jifs-journal.org" style="background-color: transparent; text-transform: lowercase;"><div class="hover-link" style="display: inline-block;">editor@jifs-journal.org</div></a></td></tr>
# </table>
# </td>
# <td width="1%">&amp;nbsp</td>
# </tr>
# </table>
# </span>
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <hr style="height:1pt; margin: 0; padding: 0" width="100%"/>
# </div>
# </td>
# </tr><tr>
# <td valign="top">
# <div style="border: none;" width="100%">
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <span style="font-size: 10pt;">
# <table width="100%">
# <tr>
# <td width="2%">&amp;nbsp</td>
# <td valign="top" width="20%"><a href="https://jims-journal.org" style="background-color: transparent;"><img alt="" height="200px" src="images\Journals\Covers\JIMS.jpg" style="margin:auto; display:inline-block; border-top: 1px solid #DDDDDD; border-right: 1px solid #DDDDDD; border-radius: 0; box-shadow: -2px 2px 2px #444444;" width="151px"/></a></td>
# <td width="2%">&amp;nbsp</td>
# <td valign="top">
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Title:</b></td><td valign="top"><a class="hover-link" href="https://jims-journal.org" style="background-color: transparent;">JOURNAL OF INTERNATIONAL MANAGEMENT STUDIES</a></td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>ISSN:</b></td><td valign="top">1930-6105</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>E-ISSN:</b></td><td valign="top">2378-9557</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Frequency:</b></td><td valign="top">0 to 3 Issues Per Year</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Acceptance:</b></td><td valign="top">21% of submitted papers</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Editor's E-mail:</b></td><td valign="top"><a href="mailto:editor@jims-journal.org" style="background-color: transparent; text-transform: lowercase;"><div class="hover-link" style="display: inline-block;">editor@jims-journal.org</div></a></td></tr>
# </table>
# </td>
# <td width="1%">&amp;nbsp</td>
# </tr>
# </table>
# </span>
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <hr style="height:1pt; margin: 0; padding: 0" width="100%"/>
# </div>
# </td>
# </tr><tr>
# <td valign="top">
# <div style="border: none;" width="100%">
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <span style="font-size: 10pt;">
# <table width="100%">
# <tr>
# <td width="2%">&amp;nbsp</td>
# <td valign="top" width="20%"><a href="https://rbr-journal.org" style="background-color: transparent;"><img alt="" height="200px" src="images\Journals\Covers\RBR.jpg" style="margin:auto; display:inline-block; border-top: 1px solid #DDDDDD; border-right: 1px solid #DDDDDD; border-radius: 0; box-shadow: -2px 2px 2px #444444;" width="151px"/></a></td>
# <td width="2%">&amp;nbsp</td>
# <td valign="top">
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Title:</b></td><td valign="top"><a class="hover-link" href="https://rbr-journal.org" style="background-color: transparent;">REVIEW OF BUSINESS RESEARCH</a></td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>ISSN:</b></td><td valign="top">1546-2609</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>E-ISSN:</b></td><td valign="top">2378-9670</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Frequency:</b></td><td valign="top">2 Issues Per Year</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Acceptance:</b></td><td valign="top">22% of submitted papers</td></tr>
# </table>
# <table width="100%">
# <tr><td valign="top" width="27%"><b>Editor's E-mail:</b></td><td valign="top"><a href="mailto:editor@rbr-journal.org" style="background-color: transparent; text-transform: lowercase;"><div class="hover-link" style="display: inline-block;">editor@rbr-journal.org</div></a></td></tr>
# </table>
# </td>
# <td width="1%">&amp;nbsp</td>
# </tr>
# </table>
# </span>
# <hr style="height:15pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <hr style="height:1pt; margin: 0; padding: 0" width="100%"/>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </div>
# <input id="hidTAB" name="hidTAB" type="hidden" value="image"/>
# <input id="hidReviewerCountry" name="hidReviewerCountry" type="hidden" value="image"/>
# </div>
# </div>
# <hr style="height:5pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# </div>
# </div>
# <div id="third" style=" min-height: 100%;">
# <div onkeypress="javascript:return WebForm_FireDefaultButton(event, 'btn_MenuSearch')">
# <span style="font-size: 11pt;">
# <div style="padding-left: 10px; padding-right: 10px; margin-top:175px; position: relative; border: none; ">
# <div style="box-shadow: -3px 3px 3px black; background-color: #555555; height: 32px; border-top-left-radius: 10px; border-top-right-radius: 10px; width: 183px; display: table-cell; vertical-align:middle; padding-left: 0px;">
# <span style="color: #fff; font-size: 14pt; padding-left: 24px;">Search</span>
# <hr style="height:1pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <img alt="" height="209px" src="images/Journals/Covers/IJBS.jpg" style="margin:auto; display: block; margin: auto; border: none; " width="160px"/>
# <hr style="height:6pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <div style="padding-left: 5px; padding-right: 5px;"><table width="100%"><tr><td width="70%"><input class="border-tb" id="tb_SearchMenu" name="tb_SearchMenu" placeholder="Search Articles  " style="width:100%;" type="text"/></td><td><input id="btn_MenuSearch" name="btn_MenuSearch" style="border-top-right-radius: 20px; border-bottom-right-radius: 20px; background-color: #016ACF; color: white; outline: 0;" type="submit" value="Search"/></td></tr></table></div>
# <hr style="height:6pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# </div>
# </div>
# </span>
# <div style="padding-left: 0px; padding-right: 0px; margin-top:0px; position: relative; ">
# </div>
# </div>
# <div style="padding-left: 10px; padding-right: 10px; margin-top:20px; position: relative; ">
# <div style="box-shadow: -3px 3px 3px black; background-color: #555555; height: 32px; border-top-left-radius: 10px; border-top-right-radius: 10px; width: 183px; display: table-cell; vertical-align:middle; padding-left: 0px;">
# <hr style="height:7pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <input alt="" id="ImageButton1" name="ImageButton1" onclick="document.location.href = 'http://www.iThenticate.com'; return false;" src="images/Partners/ithenticate-button-75.jpg" style="height:65px;width:160px;border-width:0px;margin:auto; display: block; margin: auto; border: none; border-top-left-radius: 10px; border-top-right-radius: 10px; border-bottom-left-radius: 10px; border-bottom-right-radius: 10px; " type="image"/>
# <hr style="height:5pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <div style="padding-left: 6px; padding-right: 6px; position: relative; line-height: 1.0;"><span style="font-size: 13px; color: #ffffff;">The iThenticate software checks papers against millions of published scholarly works, and billions of web content. Authors, researchers and freelancers can also use the iThenticate system to screen their work before submission by visiting <a class="hover-link2" href="http://www.ithenticate.com/" style="background-color: transparent;"><b>ithenticate.com</b>.</a></span></div>
# <hr style="height:5pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# </div>
# </div>
# <div style="padding-left: 10px; padding-right: 10px; margin-top:20px; position: relative; ">
# <div style="box-shadow: -3px 3px 3px black; background-color: #555555; height: 32px; border-top-left-radius: 10px; border-top-right-radius: 10px; width: 183px; display: table-cell; vertical-align:middle; padding-left: 0px;">
# <hr style="height:7pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <input alt="" id="ImageButton2" name="ImageButton2" onclick="document.location.href = 'http://www.portico.org/digital-preservation/'; return false;" src="images/Partners/portico_logo30.gif" style="height:107px;width:160px;border-width:0px;margin:auto; display: block; margin: auto; border: none; border-top-left-radius: 10px; border-top-right-radius: 10px; border-bottom-left-radius: 10px; border-bottom-right-radius: 10px; " type="image"/>
# <hr style="height:5pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# <div style="padding-left: 6px; padding-right: 6px; position: relative; line-height: 1.0;"><span style="font-size: 13px; color: #ffffff;">All articles pulbished in IJBS are archived with <a class="hover-link2" href="http://www.portico.org/digital-preservation/" style="background-color: transparent;"><b>Portico.</b></a> Portico is among the largest community-supported digital archives in the world. Working with libraries and publishers, Portico preserves e-journals, e-books, and other electronic scholarly content to ensure researchers and students will have access to it in the future.</span></div>
# <hr style="height:5pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# </div>
# </div>
# <hr style="height:5pt; visibility:hidden; margin: 0; padding: 0" width="100%"/>
# </div>
# </div>
# </section>
# </div><!-- End div_WorkSpace -->
# <script type="text/javascript">
# //<![CDATA[
# Sys.Application.initialize();
# Sys.Application.add_init(function() {
#     $create(AjaxControlToolkit.TextBoxWatermarkBehavior, {"ClientStateFieldID":"TextBoxWatermarkExtender_txtname_ClientState","WatermarkCssClass":"watermarkedred form-control","WatermarkText":" ","id":"TextBoxWatermarkExtender_txtname"}, null, null, $get("txtname"));
# });
# Sys.Application.add_init(function() {
#     $create(AjaxControlToolkit.TextBoxWatermarkBehavior, {"ClientStateFieldID":"TextBoxWatermarkExtender_txtemail_ClientState","WatermarkCssClass":"watermarkedred form-control","WatermarkText":" ","id":"TextBoxWatermarkExtender_txtemail"}, null, null, $get("txtemail"));
# });
# Sys.Application.add_init(function() {
#     $create(AjaxControlToolkit.TextBoxWatermarkBehavior, {"ClientStateFieldID":"TextBoxWatermarkExtender_TextBox1_ClientState","WatermarkCssClass":"watermarkedred form-control","WatermarkText":" ","id":"TextBoxWatermarkExtender_TextBox1"}, null, null, $get("TextBox1"));
# });
# //]]>
# </script>
# </form>
# <h2 class="text-center">
# <span style="font-weight: normal; font-size: 13px; color: #000000; font-family:Helvetica;">© 2020 <b><a class="hover-link" href="https://ijbs-journal.org" style="background-color: #eeeeee;">IJBS-JOURNAL.ORG</a></b>. All Rights Reserved.</span>
# <br/>
# </h2>
# </body>
# </html>

# %%
https://ijbs-journal.org/IJBS-JOURNAL/Documents/Abstracts/IJBS-12-4_Abstracts.pdf
jbs_url = 'https://www.emerald.com'
headers = {
    'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'
    }
jbs_html = sleep_get(jbs_url + '/insight/publication/issn/0275-6668',
                     headers = headers)
jbs_soup = BeautifulSoup(jbs_html.content, 'lxml')

# %%
# 🅐 Get URLs for all of the issues. These are conveniently available on a single
#    root page.
jbs_title_abstr = {issue.attrs.get('title')\
                              .replace('.', '')\
                              .lower(): {'ToC_href' : issue.attrs.get('href')}
                    for issue in jbs_soup.find_all('a', {'class' : 'intent_tocIssueLink'})}

# %%
# 🅑 Now get the article titles and the URLs to their abstract pages.
#    ⓵ First define this via a function that parses the issue ToC and returns an
#       enumarated dictionary.
def get_issue_ToC(root_url, issue):
    return\
    dict(enumerate([{'art_title' : article.find('h4').text.lower(),
                     'art_href' : article.find('h4').find('a').attrs.get('href')}
                       for article in BeautifulSoup(sleep_get(jbs_url + jbs_title_abstr.get(issue).get('ToC_href'),
                                                              headers = headers).content,
                                                    'lxml').find('div', {'id' : 'publicationTabContent'})\
                                                           .find_all('div', {'class' : 'col'})
                        if article.find('h4') is not None]))
#
#    ⓶ Next, cycle through the issues.  We use try-except logic.
issues_done = list()
issues_missed = list()
for issue in jbs_title_abstr.keys():
    try:
        jbs_title_abstr.get(issue).update({'issue_toc' : get_issue_ToC(jbs_url, issue)})
        print('{}, {} articles, success at {}'.format(issue, 
                                                      str(len(jbs_title_abstr.get(issue).get('issue_toc'))),
                                                      datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))
        issues_done.append(issue)
    except:
        print('{} failure at {}'.format(issue, datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))
        issues_missed.append(issue)
        
print('done')

with io.open('./data/jbs_title_abstr.json', 'w', encoding = 'utf-8') as f:
    json.dump(jbs_title_abstr, 
              f, 
              ensure_ascii = False, 
              indent = 4)

# %%
for issue in issues_missed:
    try:
        jbs_title_abstr.get(issue).update({'issue_toc' : get_issue_ToC(jbs_url, issue)})
        print('{}, {} articles, success at {}'.format(issue, 
                                                      str(len(jbs_title_abstr.get(issue).get('issue_toc'))),
                                                      datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))
        issues_done.append(issue)
    except:
        print('{} failure at {}'.format(issue, datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))
        issues_missed.append(issue)
        
print('done')

# %%
issue = np.random.choice(a = list(jbs_title_abstr.keys()),
                         size = 1).item(0)
article = np.random.choice(a = list(jbs_title_abstr.get(issue).get('issue_toc').keys()),
                           size = 1).item(0)
title = jbs_title_abstr.get(issue).get('issue_toc').get(article).get('art_title')
url = jbs_url + jbs_title_abstr.get(issue).get('issue_toc').get(article).get('art_href')
print(f'Issue : {issue}\nArticle : {article}\nTitle : {title}\nURL : {url}')

# %%
# 🅒 Now get the article abstracts themselves.  Each is on a dictinct page
#    for the article.
#    ⓵ Define a function that harvests abstract and publication date
#       given url for an article page.
def get_article_abstract(article_url):
    # ⓐ Get the page's html itself.
    article_soup = BeautifulSoup(sleep_get(article_url,
                                           headers = headers).content,
                                  'lxml')
    #
    # ⓑ Harvest the publication date.
    pub_date = article_soup.find('div', {'class' : 'col-12 col-md-6'})\
                            .find('span', {'class' : 'intent_journal_publication_date'})\
                            .text\
                            .split(': ')
    #
    # ⓒ Get the abstract.  In later issues, it may be distributed across multiple
    #    text blocks.  We need to get them all.
    abstr_blocks =  [abstr_block.find('p').text\
                                          .lower()
                    for abstr_block in article_soup.find_all('section', {'class' : 'intent_sub_content Abstract__block__text'})]
    #
    # ⓓ Return a dictionary item containing the abstract — all of its blocks joined into a single string —
    #    and the publication date.
    return\
    {'abstract' : ' '.join(abstr_blocks),
     'pub_date' : pub_date[1]}
#
#   ⓶ Next, cycle through issues and articles.  We harvest the pub dates and abstracts,
#      adding them to each article's dictionary value.

# %%
article_count = 0

for issue in issues_done:
    article_complete = list()
    article_missed = list()
    for article in jbs_title_abstr.get(issue).get('issue_toc').keys():
        try:
            # ⓐ Get the attributes we have thus far for the specific article.  This is
            #    a dictionary item in our master dictionary, jbs_title_abstract.
            article_value = jbs_title_abstr.get(issue).get('issue_toc').get(article) 
            #
            # ⓑ Get the abstract and the publication date, using the internal function
            #    `get_article_abstract`.  This takes the previously-obtained URL fragment
            #    as its argument and returns a dictionary object.
            abstr_pubdate = get_article_abstract(jbs_url + article_value.get('art_href'))
            #
            # ⓒ Add the abstract and publication date to the article's dictionary value.
            #   We use the dictionary.update method, which is an in-place operation.
            article_value.update(abstr_pubdate)
            #
            # ⓓ Add the article title to the `article_complete` list, for 
            #    progress/completion-accountingn purposes.
            article_complete.append(article_value.get('art_title'))
            #
            # ⓔ Increment the article counter.
            article_count += 1
            #print(f'article count : {article_count}')
            #
            # ⓕ Save the dictionary as a json file each tenth article.
            if article_count % 10 == 0:
                with io.open('./data/jbs_title_abstr.json', 'w', encoding = 'utf-8') as f:
                    json.dump(jbs_title_abstr, 
                              f, 
                              ensure_ascii = False, 
                              indent = 4)
                time_now = datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')
                print(f'Writing {article_count}th article to json at time {time_now}.')            
        except:
            article_missed.append(article_value.get('art_title'))
    print('{}, {} articles, success at {}'.format(issue, 
                                                  str(len(article_complete)),
                                                  datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))

    #
    # ⓖ Add the article_complete, article_missed lists to our issue-dictionary object.
    #    Again, use the in-place operation dictionary.update.
    jbs_title_abstr.get(issue).update({'article_complete' : article_complete,
                                       'article_missed' : article_missed})
    #
with io.open('./data/jbs_title_abstr.json', 'w', encoding = 'utf-8') as f:
    json.dump(jbs_title_abstr, 
              f, 
              ensure_ascii = False, 
              indent = 4)
time_now = datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')
print(f'Writing {article_count}th article to json at time {time_now}.')            
#
print('Done at {}'.format(datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))

# %%
article_count
