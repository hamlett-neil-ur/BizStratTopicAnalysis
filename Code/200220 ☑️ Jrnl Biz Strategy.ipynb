# %% [markdown]
# ## Purpose.
#
# Here we collect abstracts and titles from [*Strategic Management Journal*](https://onlinelibrary.wiley.com/journal/10970266), flagship publication of the [Strategic Management Society](https://www.strategicmanagement.net/).  This information is to be used as part of an attempt to apply text classification to charting the progression of business strategy.
#
# ## Approach.
#
# Titles and abstracts are available without paywall login. But we have to do this in ***three stages***.
#
# ⓵ **Get the URL for the each volume**. We start with the journal's hope page.  Our essential information is embedded in a frame depicted below on the right-hand side of the page.
#
# ⓶ **Get a list of issue URLs**.  Each volume page contains thumbnail images of individual issues. These include URLs to the individual isses.
#
# ⓷ **Collect lists of titles**.  Follow each issue's URL to its issue table of contents. The tables of contents contain titles, as well as URLs to pages for individual articles.
#
# ⓸ **Collect abstracts**.  Abstracts are accessible from individual articles. We have to get the abstracts from these individual-article pages.

# %%
# Import libaries
import requests as req
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import itertools as it
import json
import io
from copy import deepcopy
import datetime

# %%
# We use lots of list-comprehension, which drives requests.get operations.
# We need to "throttle" these, so as to avoid the appearance of a DDoS
# attack.  We accomplish this by a get_sleep function.  This function 
# executes a req.get operation, returning the result, with a one-second
# delay.
def sleep_get(url, headers):
    time.sleep(np.random.uniform(low = 1,
                                 high = 2.5))
    return(req.get(url,
                   headers = headers))
#
# Partition a list into a specified number of bins.  Our inputs
# are:
# ⧐ parted_list is the list to be partitioned;
# ⧐ partition_counts specifies the number of bins into which
#   parted_list is divided.
# We produce an enumerated dictionary of the list partitions.
def partition_list(parted_list, partition_counts):
    parted_list = np.sort(np.array(parted_list))
    partition_len = int(np.ceil(len(parted_list)/partition_counts))
    partitions = [np.array(object = range(partition_len)) + part * partition_len
                     for part in range(partition_counts)]
    partitions[-1] = np.arange(start = partitions[-1][0],
                               stop = parted_list.shape[0])
    return dict(enumerate([list(parted_list[part])
                             for part in partitions]))

# %%
jbs_url = 'https://www.emerald.com'
headers = {
    'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'
    }
jbs_html = sleep_get(jbs_url + '/insight/publication/issn/0275-6668',
                     headers = headers)
jbs_soup = BeautifulSoup(jbs_html.content, 'lxml')

# %%
# 🅐 Get URLs for all of the issues. These are conveniently available on a single
#    root page.
jbs_title_abstr = {issue.attrs.get('title')\
                              .replace('.', '')\
                              .lower(): {'ToC_href' : issue.attrs.get('href')}
                    for issue in jbs_soup.find_all('a', {'class' : 'intent_tocIssueLink'})}

# %%
# 🅑 Now get the article titles and the URLs to their abstract pages.
#    ⓵ First define this via a function that parses the issue ToC and returns an
#       enumarated dictionary.
def get_issue_ToC(root_url, issue):
    return\
    dict(enumerate([{'art_title' : article.find('h4').text.lower(),
                     'art_href' : article.find('h4').find('a').attrs.get('href')}
                       for article in BeautifulSoup(sleep_get(jbs_url + jbs_title_abstr.get(issue).get('ToC_href'),
                                                              headers = headers).content,
                                                    'lxml').find('div', {'id' : 'publicationTabContent'})\
                                                           .find_all('div', {'class' : 'col'})
                        if article.find('h4') is not None]))
#
#    ⓶ Next, cycle through the issues.  We use try-except logic.
issues_done = list()
issues_missed = list()
for issue in jbs_title_abstr.keys():
    try:
        jbs_title_abstr.get(issue).update({'issue_toc' : get_issue_ToC(jbs_url, issue)})
        print('{}, {} articles, success at {}'.format(issue, 
                                                      str(len(jbs_title_abstr.get(issue).get('issue_toc'))),
                                                      datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))
        issues_done.append(issue)
    except:
        print('{} failure at {}'.format(issue, datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))
        issues_missed.append(issue)
        
print('done')

with io.open('./data/jbs_title_abstr.json', 'w', encoding = 'utf-8') as f:
    json.dump(jbs_title_abstr, 
              f, 
              ensure_ascii = False, 
              indent = 4)
# Out:
# volume 41 issue 1, 8 articles, success at 20-03-01, 190514Z
# volume 40 issue 6, 7 articles, success at 20-03-01, 190516Z
# volume 40 issue 5, 7 articles, success at 20-03-01, 190518Z
# volume 40 issue 4, 7 articles, success at 20-03-01, 190520Z
# volume 40 issue 3, 7 articles, success at 20-03-01, 190522Z
# volume 40 issue 2, 8 articles, success at 20-03-01, 190525Z
# volume 40 issue 1, 6 articles, success at 20-03-01, 190529Z
# volume 39 issue 6, 8 articles, success at 20-03-01, 190531Z
# volume 39 issue 5, 7 articles, success at 20-03-01, 190533Z
# volume 39 issue 4, 7 articles, success at 20-03-01, 190535Z
# volume 39 issue 3, 7 articles, success at 20-03-01, 190537Z
# volume 39 issue 2, 7 articles, success at 20-03-01, 190539Z
# volume 39 issue 1, 7 articles, success at 20-03-01, 190541Z
# volume 38 issue 6, 10 articles, success at 20-03-01, 190542Z
# volume 38 issue 5, 6 articles, success at 20-03-01, 190545Z
# volume 38 issue 4, 6 articles, success at 20-03-01, 190546Z
# volume 38 issue 3, 6 articles, success at 20-03-01, 190548Z
# volume 38 issue 2, 9 articles, success at 20-03-01, 190550Z
# volume 38 issue 1, 6 articles, success at 20-03-01, 190551Z
# volume 37 issue 6, 6 articles, success at 20-03-01, 190554Z
# volume 37 issue 5, 6 articles, success at 20-03-01, 190555Z
# volume 37 issue 4, 6 articles, success at 20-03-01, 190557Z
# volume 37 issue 3, 7 articles, success at 20-03-01, 190558Z
# volume 37 issue 2, 7 articles, success at 20-03-01, 190601Z
# volume 37 issue 1, 7 articles, success at 20-03-01, 190602Z
# volume 36 issue 6, 7 articles, success at 20-03-01, 190604Z
# volume 36 issue 5, 7 articles, success at 20-03-01, 190606Z
# volume 36 issue 4, 7 articles, success at 20-03-01, 190607Z
# volume 36 issue 3, 7 articles, success at 20-03-01, 190608Z
# volume 36 issue 2, 6 articles, success at 20-03-01, 190611Z
# volume 36 issue 1, 6 articles, success at 20-03-01, 190612Z
# volume 35 issue 6, 7 articles, success at 20-03-01, 190614Z
# volume 35 issue 5, 8 articles, success at 20-03-01, 190615Z
# volume 35 issue 4, 7 articles, success at 20-03-01, 190616Z
# volume 35 issue 3, 8 articles, success at 20-03-01, 190618Z
# volume 35 issue 2, 8 articles, success at 20-03-01, 190619Z
# volume 35 issue 1, 8 articles, success at 20-03-01, 190621Z
# volume 34 issue 6, 6 articles, success at 20-03-01, 190624Z
# volume 34 issue 5, 7 articles, success at 20-03-01, 190626Z
# volume 34 issue 4, 6 articles, success at 20-03-01, 190628Z
# volume 34 issue 3, 7 articles, success at 20-03-01, 190629Z
# volume 34 issue 2, 7 articles, success at 20-03-01, 190631Z
# volume 34 issue 1, 7 articles, success at 20-03-01, 190632Z
# volume 33 issue 6, 7 articles, success at 20-03-01, 190634Z
# volume 33 issue 5, 8 articles, success at 20-03-01, 190636Z
# volume 33 issue 4, 7 articles, success at 20-03-01, 190638Z
# volume 33 issue 3, 7 articles, success at 20-03-01, 190639Z
# volume 33 issue 2, 8 articles, success at 20-03-01, 190642Z
# volume 33 issue 1, 8 articles, success at 20-03-01, 190643Z
# volume 32 issue 6, 8 articles, success at 20-03-01, 190645Z
# volume 32 issue 5, 8 articles, success at 20-03-01, 190648Z
# volume 32 issue 4, 8 articles, success at 20-03-01, 190649Z
# volume 32 issue 3, 7 articles, success at 20-03-01, 190651Z
# volume 32 issue 2 failure at 20-03-01, 190723Z
# volume 32 issue 1, 10 articles, success at 20-03-01, 190725Z
# volume 31 issue 6, 8 articles, success at 20-03-01, 190726Z
# volume 31 issue 5, 9 articles, success at 20-03-01, 190728Z
# volume 31 issue 4, 11 articles, success at 20-03-01, 190730Z
# volume 31 issue 3, 9 articles, success at 20-03-01, 190732Z
# volume 31 issue 2, 9 articles, success at 20-03-01, 190734Z
# volume 31 issue 1, 3 articles, success at 20-03-01, 190736Z
# volume 30 issue 6, 10 articles, success at 20-03-01, 190739Z
# volume 30 issue 5, 9 articles, success at 20-03-01, 190741Z
# volume 30 issue 4, 10 articles, success at 20-03-01, 190743Z
# volume 30 issue 2/3, 12 articles, success at 20-03-01, 190744Z
# volume 30 issue 1, 9 articles, success at 20-03-01, 190746Z
# volume 29 issue 6, 11 articles, success at 20-03-01, 190748Z
# volume 29 issue 5, 10 articles, success at 20-03-01, 190750Z
# volume 29 issue 4, 9 articles, success at 20-03-01, 190752Z
# volume 29 issue 3, 9 articles, success at 20-03-01, 190753Z
# volume 29 issue 2, 8 articles, success at 20-03-01, 190755Z
# volume 29 issue 1, 9 articles, success at 20-03-01, 190757Z
# volume 28 issue 6, 9 articles, success at 20-03-01, 190759Z
# volume 28 issue 5, 9 articles, success at 20-03-01, 190801Z
# volume 28 issue 4, 10 articles, success at 20-03-01, 190803Z
# volume 28 issue 3, 11 articles, success at 20-03-01, 190805Z
# volume 28 issue 2, 10 articles, success at 20-03-01, 190807Z
# volume 28 issue 1, 12 articles, success at 20-03-01, 190809Z
# volume 27 issue 6, 11 articles, success at 20-03-01, 190811Z
# volume 27 issue 5, 10 articles, success at 20-03-01, 190812Z
# volume 27 issue 4, 10 articles, success at 20-03-01, 190815Z
# volume 27 issue 3, 9 articles, success at 20-03-01, 190817Z
# volume 27 issue 2, 9 articles, success at 20-03-01, 190819Z
# volume 27 issue 1, 9 articles, success at 20-03-01, 190821Z
# volume 26 issue 6, 12 articles, success at 20-03-01, 190824Z
# volume 26 issue 5, 13 articles, success at 20-03-01, 190826Z
# volume 26 issue 4, 11 articles, success at 20-03-01, 190827Z
# volume 26 issue 3, 11 articles, success at 20-03-01, 190829Z
# volume 26 issue 2 failure at 20-03-01, 190832Z
# volume 26 issue 1, 12 articles, success at 20-03-01, 190834Z
# volume 25 issue 6, 13 articles, success at 20-03-01, 190835Z
# volume 25 issue 5, 13 articles, success at 20-03-01, 190837Z
# volume 25 issue 4, 13 articles, success at 20-03-01, 190839Z
# volume 25 issue 3, 14 articles, success at 20-03-01, 190840Z
# volume 25 issue 2, 14 articles, success at 20-03-01, 190842Z
# volume 25 issue 1, 13 articles, success at 20-03-01, 190843Z
# volume 24 issue 6, 10 articles, success at 20-03-01, 190844Z
# volume 24 issue 5, 10 articles, success at 20-03-01, 190847Z
# volume 24 issue 4, 10 articles, success at 20-03-01, 190848Z
# volume 24 issue 3 failure at 20-03-01, 190851Z
# volume 24 issue 2, 7 articles, success at 20-03-01, 190853Z
# volume 24 issue 1, 9 articles, success at 20-03-01, 190855Z
# volume 23 issue 6, 12 articles, success at 20-03-01, 190857Z
# volume 23 issue 5, 10 articles, success at 20-03-01, 190859Z
# volume 23 issue 4, 11 articles, success at 20-03-01, 190900Z
# volume 23 issue 3, 13 articles, success at 20-03-01, 190902Z
# volume 23 issue 2, 12 articles, success at 20-03-01, 190903Z
# volume 23 issue 1, 13 articles, success at 20-03-01, 190905Z
# volume 22 issue 6, 11 articles, success at 20-03-01, 190906Z
# volume 22 issue 5, 10 articles, success at 20-03-01, 190909Z
# volume 22 issue 4, 13 articles, success at 20-03-01, 190911Z
# volume 22 issue 3, 12 articles, success at 20-03-01, 190914Z
# volume 22 issue 2, 13 articles, success at 20-03-01, 190915Z
# volume 22 issue 1, 12 articles, success at 20-03-01, 190917Z
# volume 21 issue 6, 13 articles, success at 20-03-01, 190919Z
# volume 21 issue 5, 10 articles, success at 20-03-01, 190921Z
# volume 21 issue 4, 13 articles, success at 20-03-01, 190923Z
# volume 21 issue 3, 13 articles, success at 20-03-01, 190926Z
# volume 21 issue 2, 14 articles, success at 20-03-01, 190928Z
# volume 21 issue 1, 12 articles, success at 20-03-01, 190930Z
# volume 20 issue 6, 11 articles, success at 20-03-01, 190932Z
# volume 20 issue 5, 8 articles, success at 20-03-01, 190933Z
# volume 20 issue 4, 11 articles, success at 20-03-01, 190935Z
# volume 20 issue 3, 12 articles, success at 20-03-01, 190936Z
# volume 20 issue 2, 12 articles, success at 20-03-01, 190938Z
# volume 20 issue 1, 10 articles, success at 20-03-01, 190940Z
# volume 19 issue 6, 9 articles, success at 20-03-01, 190941Z
# volume 19 issue 5, 12 articles, success at 20-03-01, 190944Z
# volume 19 issue 4, 13 articles, success at 20-03-01, 190946Z
# volume 19 issue 3, 14 articles, success at 20-03-01, 190948Z
# volume 19 issue 2, 15 articles, success at 20-03-01, 190950Z
# volume 19 issue 1, 12 articles, success at 20-03-01, 190952Z
# volume 18 issue 6, 14 articles, success at 20-03-01, 190953Z
# volume 18 issue 5, 11 articles, success at 20-03-01, 190956Z
# volume 18 issue 4, 13 articles, success at 20-03-01, 190958Z
# volume 18 issue 3, 15 articles, success at 20-03-01, 190959Z
# volume 18 issue 2, 14 articles, success at 20-03-01, 191001Z
# volume 18 issue 1, 13 articles, success at 20-03-01, 191003Z
# volume 17 issue 6, 11 articles, success at 20-03-01, 191004Z
# volume 17 issue 5, 10 articles, success at 20-03-01, 191007Z
# volume 17 issue 4, 13 articles, success at 20-03-01, 191008Z
# volume 17 issue 3, 12 articles, success at 20-03-01, 191010Z
# volume 17 issue 2, 13 articles, success at 20-03-01, 191011Z
# volume 17 issue 1, 12 articles, success at 20-03-01, 191012Z
# volume 16 issue 6, 17 articles, success at 20-03-01, 191014Z
# volume 16 issue 5, 17 articles, success at 20-03-01, 191016Z
# volume 16 issue 4, 10 articles, success at 20-03-01, 191018Z
# volume 16 issue 3, 11 articles, success at 20-03-01, 191020Z
# volume 16 issue 2, 12 articles, success at 20-03-01, 191022Z
# volume 16 issue 1, 12 articles, success at 20-03-01, 191025Z
# volume 15 issue 6, 10 articles, success at 20-03-01, 191027Z
# volume 15 issue 5, 10 articles, success at 20-03-01, 191029Z
# volume 15 issue 4, 11 articles, success at 20-03-01, 191030Z
# volume 15 issue 3, 9 articles, success at 20-03-01, 191032Z
# volume 15 issue 2, 11 articles, success at 20-03-01, 191034Z
# volume 15 issue 1, 12 articles, success at 20-03-01, 191036Z
# volume 14 issue 6, 14 articles, success at 20-03-01, 191039Z
# volume 14 issue 5, 14 articles, success at 20-03-01, 191041Z
# volume 14 issue 4, 15 articles, success at 20-03-01, 191043Z
# volume 14 issue 3, 15 articles, success at 20-03-01, 191044Z
# volume 14 issue 2, 11 articles, success at 20-03-01, 191046Z
# volume 14 issue 1, 7 articles, success at 20-03-01, 191048Z
# volume 13 issue 6, 11 articles, success at 20-03-01, 191051Z
# volume 13 issue 5, 10 articles, success at 20-03-01, 191053Z
# volume 13 issue 4, 12 articles, success at 20-03-01, 191055Z
# volume 13 issue 3, 12 articles, success at 20-03-01, 191056Z
# volume 13 issue 2, 13 articles, success at 20-03-01, 191058Z
# volume 13 issue 1, 12 articles, success at 20-03-01, 191100Z
# volume 12 issue 6, 13 articles, success at 20-03-01, 191103Z
# volume 12 issue 5, 13 articles, success at 20-03-01, 191105Z
# volume 12 issue 4, 13 articles, success at 20-03-01, 191107Z
# volume 12 issue 3, 14 articles, success at 20-03-01, 191109Z
# volume 12 issue 2, 14 articles, success at 20-03-01, 191110Z
# volume 12 issue 1, 11 articles, success at 20-03-01, 191112Z
# volume 11 issue 6, 13 articles, success at 20-03-01, 191114Z
# volume 11 issue 5, 13 articles, success at 20-03-01, 191115Z
# volume 11 issue 4, 12 articles, success at 20-03-01, 191117Z
# volume 11 issue 3, 13 articles, success at 20-03-01, 191118Z
# volume 11 issue 2 failure at 20-03-01, 191150Z
# volume 11 issue 1, 14 articles, success at 20-03-01, 191152Z
# volume 10 issue 6, 13 articles, success at 20-03-01, 191154Z
# volume 10 issue 5, 12 articles, success at 20-03-01, 191158Z
# volume 10 issue 4 failure at 20-03-01, 191229Z
# volume 10 issue 3, 13 articles, success at 20-03-01, 191230Z
# volume 10 issue 2, 14 articles, success at 20-03-01, 191232Z
# volume 10 issue 1, 12 articles, success at 20-03-01, 191234Z
# volume 9 issue 6, 13 articles, success at 20-03-01, 191236Z
# volume 9 issue 5, 14 articles, success at 20-03-01, 191238Z
# volume 9 issue 4, 15 articles, success at 20-03-01, 191239Z
# volume 9 issue 3, 14 articles, success at 20-03-01, 191241Z
# volume 9 issue 2, 13 articles, success at 20-03-01, 191242Z
# volume 8 issue 2, 12 articles, success at 20-03-01, 191245Z
# volume 8 issue 1, 11 articles, success at 20-03-01, 191247Z
# volume 7 issue 4, 12 articles, success at 20-03-01, 191248Z
# volume 7 issue 3, 11 articles, success at 20-03-01, 191251Z
# volume 7 issue 2, 12 articles, success at 20-03-01, 191253Z
# volume 7 issue 1, 10 articles, success at 20-03-01, 191255Z
# volume 6 issue 4, 12 articles, success at 20-03-01, 191257Z
# volume 6 issue 3, 10 articles, success at 20-03-01, 191259Z
# volume 6 issue 2, 10 articles, success at 20-03-01, 191301Z
# volume 6 issue 1, 11 articles, success at 20-03-01, 191303Z
# volume 5 issue 4, 13 articles, success at 20-03-01, 191306Z
# volume 5 issue 3, 11 articles, success at 20-03-01, 191307Z
# volume 5 issue 2, 17 articles, success at 20-03-01, 191308Z
# volume 5 issue 1, 14 articles, success at 20-03-01, 191310Z
# volume 4 issue 3, 12 articles, success at 20-03-01, 191313Z
# volume 4 issue 2, 12 articles, success at 20-03-01, 191316Z
# volume 4 issue 1, 14 articles, success at 20-03-01, 191318Z
# volume 3 issue 4, 17 articles, success at 20-03-01, 191319Z
# volume 3 issue 3, 12 articles, success at 20-03-01, 191321Z
# volume 3 issue 2, 10 articles, success at 20-03-01, 191323Z
# volume 3 issue 1, 11 articles, success at 20-03-01, 191325Z
# volume 2 issue 4, 10 articles, success at 20-03-01, 191326Z
# volume 2 issue 2, 10 articles, success at 20-03-01, 191328Z
# volume 2 issue 1, 13 articles, success at 20-03-01, 191330Z
# volume 1 issue 4, 12 articles, success at 20-03-01, 191331Z
# volume 1 issue 2, 12 articles, success at 20-03-01, 191333Z
# volume 1 issue 1, 10 articles, success at 20-03-01, 191335Z
# done

# %%
# 🅒 Now get the article abstracts themselves.  Each is on a dictinct page
#    for the article.
#    ⓵ Define a function that harvests abstract and publication date
#       given url for an article page.
def get_article_abstract(article_url):
    # ⓐ Get the page's html itself.
    article_soup = BeautifulSoup(sleep_get(article_url,
                                           headers = headers).content,
                                  'lxml')
    #
    # ⓑ Harvest the publication date.
    pub_date = article_soup.find('div', {'class' : 'col-12 col-md-6'})\
                            .find('span', {'class' : 'intent_journal_publication_date'})\
                            .text\
                            .split(': ')
    #
    # ⓒ Get the abstract.  In later issues, it may be distributed across multiple
    #    text blocks.  We need to get them all.
    abstr_blocks =  [abstr_block.find('p').text\
                                          .lower()
                    for abstr_block in article_soup.find_all('section', {'class' : 'intent_sub_content Abstract__block__text'})]
    #
    # ⓓ Try to get keywords.  They are only provided for more-recent years.  If we don't 
    #    find them, provide an empty-list placeholder.
    try:
        keywords = [keyword.text
                    for keyword in article_soup.find('section', {'id' : 'keywords_list'})\
                                               .find_all('a')]
    except:
        keywords = list()
    #
    # ⓔ Return a dictionary item containing the abstract — all of its blocks joined into a single string —
    #    and the publication date.
    return\
    {'abstract' : ' '.join(abstr_blocks),
     'pub_date' : pub_date[1],
     'keywords' : keywords}
#
#   ⓶ Next, cycle through issues and articles.  We harvest the pub dates and abstracts,
#      adding them to each article's dictionary value.

# %%
issues_done[:3]
# Out:
# ['volume 41 issue 1', 'volume 40 issue 6', 'volume 40 issue 5']

# %%
article_count = 0

for issue in issues_done:
    article_complete = list()
    article_missed = list()
    for article in jbs_title_abstr.get(issue).get('issue_toc').keys():
        try:
            # ⓐ Get the attributes we have thus far for the specific article.  This is
            #    a dictionary item in our master dictionary, jbs_title_abstract.
            article_value = jbs_title_abstr.get(issue).get('issue_toc').get(article) 
            #
            # ⓑ Get the abstract and the publication date, using the internal function
            #    `get_article_abstract`.  This takes the previously-obtained URL fragment
            #    as its argument and returns a dictionary object.
            abstr_pubdate = get_article_abstract(jbs_url + article_value.get('art_href'))
            #
            # ⓒ Add the abstract and publication date to the article's dictionary value.
            #   We use the dictionary.update method, which is an in-place operation.
            article_value.update(abstr_pubdate)
            #
            # ⓓ Add the article title to the `article_complete` list, for 
            #    progress/completion-accountingn purposes.
            article_complete.append(article_value.get('art_title'))
            #
            # ⓔ Increment the article counter.
            article_count += 1
            #print(f'article count : {article_count}')
            #
            # ⓕ Save the dictionary as a json file each tenth article.
            if article_count % 10 == 0:
                with io.open('./data/jbs_title_abstr.json', 'w', encoding = 'utf-8') as f:
                    json.dump(jbs_title_abstr, 
                              f, 
                              ensure_ascii = False, 
                              indent = 4)
                time_now = datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')
                print(f'Writing {article_count}th article to json at time {time_now}.')            
        except:
            article_missed.append(article_value.get('art_title'))
    print('{}, {} articles, success at {}'.format(issue, 
                                                  str(len(article_complete)),
                                                  datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))

    #
    # ⓖ Add the article_complete, article_missed lists to our issue-dictionary object.
    #    Again, use the in-place operation dictionary.update.
    jbs_title_abstr.get(issue).update({'article_complete' : article_complete,
                                       'article_missed' : article_missed})
    #
with io.open('./data/jbs_title_abstr.json', 'w', encoding = 'utf-8') as f:
    json.dump(jbs_title_abstr, 
              f, 
              ensure_ascii = False, 
              indent = 4)
time_now = datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')
print(f'Writing {article_count}th article to json at time {time_now}.')            
#
print('Done at {}'.format(datetime.datetime.utcnow().strftime('%y-%m-%d, %H%M%SZ')))
# Out:
# volume 41 issue 1, 6 articles, success at 20-03-01, 200930Z
# Writing 10th article to json at time 20-03-01, 200941Z.
# volume 40 issue 6, 7 articles, success at 20-03-01, 200948Z
# Writing 13th article to json at time 20-03-01, 200948Z.
# Done at 20-03-01, 200948Z

# %%
jbs_title_abstr.get('volume 41 issue 1').get('issue_toc')
# Out:
# {0: {'art_title': 'wanted: strategic partners for young firms eager to enter foreign markets',
#   'art_href': '/insight/content/doi/10.1108/JBS-11-2018-0196/full/html',
#   'abstract': 'this paper aims to investigate the relationship between strategic asset-seeking intent and firms’ entry strategies of foreign investment in the context of emerging market firms. this study is based on survey data of 392 chinese foreign direct investment projects. structural equation modelling is used for data analysis. with stronger strategic asset-seeking intent, emerging market multinational enterprises are likely to locate their subsidiaries in developed countries, use a wholly owned subsidiary mode and invest with greater intensity, while they do not have a clear preference in entry timing. the strategic asset-seeking intent applies not only to emerging market firms but also to small and medium firms in general that have limited resources and a need to catch up with stronger competitors. this study therefore provides guidance to these firms. this study contributes by investigating how the strategic asset-seeking intent affects firms’ strategies. the findings have practical implications for strategic managerial decisions that lead to sustained competitive advantage and improved firm performance.',
#   'pub_date': '13 January 2020',
#   'keywords': ['Entry mode strategy',
#    'Strategic asset seeking',
#    'Location strategy',
#    'FDI intensity',
#    'FDI strategies',
#    'Timing of entry']},
#  1: {'art_title': 'leveraging board talent for innovation strategy',
#   'art_href': '/insight/content/doi/10.1108/JBS-12-2018-0207/full/html',
#   'abstract': 'human capital has been traditionally viewed in terms of how an individual’s investment in knowledge, skills and abilities can lead to higher pay or promotions. more recently, human capital has been regarded as a unit-level resource using the term “human capital resources” to consider the aggregate effects of human capital. the purpose of this paper is to examine the collective human capital present in a firm’s board of directors as a valuable resource leading to superior firm outcomes. the study examined the effects on firm innovation of the scientific expertise of corporate directors, average board tenure and the presence of a firm’s founder on the board. data from a sample of pharmaceutical firms were analyzed with the dependent variable, innovation, measured as patent applications and both individual and unit-level human capital measures of the predictor variables. the results show that the presence of a founder-director is positively related to innovation and more pronounced when combined with the board’s scientific expertise. board tenure shows a relationship to innovation and is more evident in combination with the board’s aggregate level of scientific expertise. the effect of directors’ scientific expertise is also greater when measured at the board level of scientific expertise. future studies should examine these relationships within a broader context extending the research to other industries thereby incorporating wider variation in both the antecedents and measures of innovation. in addition, future studies might investigate a likely non-monotonic relationship of board tenure with strategic outcomes, recognizing the non-linear nature of effects of board tenure. in addition to the theoretical and empirical implications, this research may also inform practicing managers charged with constituting their boards of directors and provide some guidance for the recruitment and retention of board members. the research may also assist top managers and investors in knowing when the presence of a founder on the board is useful and supportive of the firm’s strategic direction. the study extends scholarly understanding of human capital theory beyond the top management team to boards of directors demonstrating the importance not only of directors’ individual capital but also how it combines with that of other directors. moreover, it enhances understanding of board characteristics beyond the bounds of demographic characteristics to show that additional qualities affect firm strategy. this research also informs managers, boards and investors how boards might be more effectively constituted to impact firm strategy.',
#   'pub_date': '13 January 2020',
#   'keywords': ['Human capital',
#    'Innovation',
#    'Governance',
#    'Board of directors',
#    'Pharmaceutical industry',
#    'Upper echelons theory',
#    'Board demographics',
#    'Critical mass theory',
#    'Human capital resource theory']},
#  2: {'art_title': 'beyond artificial intelligence: why companies need to go the extra step',
#   'art_href': '/insight/content/doi/10.1108/JBS-05-2018-0086/full/html',
#   'abstract': 'the purpose of this paper is to underscore the need for developing a meta-intelligence in companies based on a conceptual framework for combining artificial and human intelligence. this is a conceptual paper, which draws on the insights from extant theoretical and empirical research. in light of a growing trend towards artificial intelligence (ai), most companies face substantial difficulties, which often derive from an excessive emphasis on merely replacing human intelligence by means of ai. to capture the complementary benefits of artificial and human intelligence beyond mere cost savings, firms do not only need to enhance their advanced analytics while continuing to develop their human intelligence. rather, they additionally need a meta-intelligence for transforming their intelligence architecture in line with corporate strategy. consequently, the firms need intelligence3 – comprising ai, human intelligence and the meta-intelligence. the new concept of a meta-intelligence for renewing and recombining artificial and human intelligence helps to reconcile diverse findings in prior research. without this meta-intelligence, most ai initiatives will be isolated endeavors, which may have positive effects but likely will not live up to the expectations.',
#   'pub_date': '13 January 2020',
#   'keywords': ['Innovation']},
#  3: {'art_title': 'the bayer–monsanto fusion: countering brand tarnishing and rebuilding reputation',
#   'art_href': '/insight/content/doi/10.1108/JBS-10-2018-0185/full/html',
#   'abstract': 'the purpose of this paper is to investigate the antecedents, internal/external drivers and circumstances that diminish the importance of reputation and permit it to be circumvented in the context of a fusion (monsanto-bayer) and propose a comprehensive stakeholder perception-molding (“sense-giving”) model to counter reputation-damaging factors. the present study is a longitudinal case study of merging entities using an intra-organizational evolutionary perspective combined with external analysis. reputational hurdles can be successfully circumvented by a multifaceted strategy leveraging timely and tailored combinations of cognitive, conative and linguistic perception-molding strategies for effective management of diverse stakeholder perception processes spanning across identity orientation, legitimacy, posture, consistency, commitment, justification and transparency. the research is susceptible to the general limitations of case studies such as omission bias in terms of focusing on only two purposefully chosen market-leader firms involved in a merger, though every effort was made to track competitor movements, broad trends in markets and the micro- and macro-environments. the proposed heptagonal reputation circumvention perception-molding framework (figure 1) summarizes various actionable strategies to help managers develop a global vision and portfolio of strategies to proactively or reactively manage attacks on reputation. an in-depth and multi-decade study of antecedents and internal/external drivers of the successful mega-fusion of two companies with a long history of reputational shocks was leveraged to provide unique insights into the interplay of various strategies targeting diverse stakeholder perceptions. these insights were then generalized to create a comprehensive perception-molding strategic framework to help firm managers circumvent reputational tarnishment hurdles.',
#   'pub_date': '13 January 2020',
#   'keywords': ['Strategic management',
#    'Stakeholders',
#    'Sense-making',
#    'Reputation',
#    'Evolutionary perspective',
#    'Monsanto–Bayer',
#    'Perception-molding']},
#  4: {'art_title': 'the essential mix: six tools for strategy-making in the next decade',
#   'art_href': '/insight/content/doi/10.1108/JBS-09-2018-0147/full/html',
#   'abstract': 'the purpose of this paper is to provide a solution that helps reduce confusion about choice and usage of tools for strategy-making. the approach is to present a classroom-tested system that integrates new methods for applying a parsimonious set of six widely used tools, within one, comprehensive, yet succinct, procedure for strategy-making. findings, based on years of development and use of the procedure as the basis for teaching mba capstone courses in strategy, reveal that it facilitates rapid mastery of the underlying theory and practical application of the essential tools of strategy-making. practical implications include decreased tendencies for ad hoc or disjointed use of random sets of tools for strategy-making and increased capabilities to connect strategy-making and strategy-executing in an iterative process, as previous iterations of strategies that were executed by organizations are used to determine new strategies. characteristics of the procedure which are original include: merging outside-in and inside-out perspectives on strategy-making in one, succinct procedure; providing an approach with general applicability to diverse types of organizations; providing a systematic process for identifying and rating environmental characteristics, using shared, theory-based scales, applied to fully-cited, real-world data, thereby reducing reliance on unsubstantiated opinion, providing full traceability, and facilitating knowledge transfer across users and time; and linking strategy analysis to formulation. the procedure described in this article has value for professors, students, managers, consultants, and the broad spectrum of people throughout organizations who are engaged in strategy-making.',
#   'pub_date': '13 January 2020',
#   'keywords': ['Strategy', 'Strategy tools', 'Strategy formulation']},
#  5: {'art_title': 'improving the m&a success rate: identity may be the key',
#   'art_href': '/insight/content/doi/10.1108/JBS-08-2017-0115/full/html',
#   'abstract': 'the purpose of this paper is to build a model of mergers and acquisitions (m&a) performance drawing from the concept of organizational identity theory. the paper proposes that successful performance of an m&a is dependent upon two things, namely, the alignment of the organizational identities of the two merging firms and the method used to integrate them. this is a conceptual paper based on current research and uses multiple real-world examples of m&a to elaborate the proposed model and highlight scholarly and practical implications. the paper explains that the similarity of the identities of the merging organizations has a significant impact on the performance of the combined entity. furthermore, the integration method used by the merged firms influences the success of the merged entity. the use of an identity approach helps unravel new variables impacting m&a performance. a limitation of the paper is that it does not address how, over time, identity management can overcome the resistance of two merging entities. in addition to testing the proposed relationships, further research can explore these identity dynamics in unraveling an m&a performance. this paper highlights the importance of evaluating identity as an element of an m&a due diligence. practitioners should be aware of the dangers of signaling one identity integration strategy but using contradictory actions in implementation. given the importance of identity in a variety of organizational outcomes, the paper is timely in integrating the organizational identity (oi) concepts in understanding m&a performance issues. given the importance of identity in a variety of organizational outcomes, the paper is timely in integrating the oi concepts in understanding m&a performance issues.',
#   'pub_date': '13 January 2020',
#   'keywords': ['Integration',
#    'Mergers and acquisitions',
#    'Organizational identity',
#    'Identity assimilation',
#    'Identity similarity',
#    'M&A performance']},
#  6: {'art_title': 'getting employees involved in strategy planning',
#   'art_href': '/insight/content/doi/10.1108/JBS-04-2018-0060/full/html'},
#  7: {'art_title': 'alone on the ramparts',
#   'art_href': '/insight/content/doi/10.1108/JBS-08-2019-0164/full/html'}}
